# %% [markdown]
# ## The Basic Connect to LLM: Heart to Heart

# %%
# !nvidia-smi
# Out:
# Sun Feb 15 18:10:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.126.09             Driver Version: 580.126.09     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-16GB           On  |   00000000:04:00.0 Off |                  Off |
# | N/A   38C    P0             52W /  300W |   15867MiB /  16384MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !pip install flash_attn==2.5.8
# !pip install torch==2.3.1
# !pip install accelerate==0.31.0
# !pip install transformers==4.41.2

# %%
# !phi3\Scripts\activate
from transformers import AutoModelForCausalLM, AutoTokenizer
# Replace 'your_token_here' with your actual Hugging Face token
hf_token = hf_token

model= AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="auto",
    torch_dtype="auto",
trust_remote_code=True,
attn_implementation="eager",
# oad_in_8bit=True,
token=hf_token)

tokenizer= AutoTokenizer.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
       token=hf_token)

from transformers import pipeline

generator= pipeline(
    'text-generation',
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=500,
    do_sample=False)


message = [
    {"role":"user", "content":"What are top 10 native phrasal verbs in English?"}
]

output = generator(message)
print(output[0]['generated_text'])
# Out:
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 2026-02-15 17:20:40.267131: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-15 17:20:41.017449: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771176041.300836     823 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771176041.370247     823 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-02-15 17:20:42.025339: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# You are not running the flash-attention implementation, expect numerical differences.
#  Here are ten common native phrasal verbs in English, along with their meanings:
#
# 1. **Turn on** - to activate or start something, such as a device or a light.
#    - Example: "Please turn on the lights."
#
# 2. **Turn off** - to deactivate or stop something, such as a device or a light.
#    - Example: "Don't forget to turn off the computer before you leave."
#
# 3. **Look up** - to search for information in a reference source, such as a dictionary or the internet.
#    - Example: "I need to look up the capital of France."
#
# 4. **Look after** - to take care of someone or something.
#    - Example: "I'll look after the kids while you're out."
#
# 5. **Look forward to** - to anticipate or be excited about something in the future.
#    - Example: "I'm looking forward to the weekend."
#
# 6. **Look up to** - to admire or respect someone.
#    - Example: "I look up to my older sister."
#
# 7. **Look into** - to investigate or examine something.
#    - Example: "The police are looking into the robbery."
#
# 8. **Look after** - to take care of someone or something.
#    - Example: "Please look after the dog while we're away."
#
# 9. **Look down on** - to regard someone or something as inferior.
#    - Example: "I don't look down on people who work in retail."
#
# 10. **Look forward to** - to anticipate or be excited about something in the future.
#     - Example: "I'm looking forward to the new season of my favorite TV show."
